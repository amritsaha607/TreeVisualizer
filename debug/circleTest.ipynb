# %%
import sys
sys.path.append('../')

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

from utils import Circle, makeCircles, showCircle

# %%
# data = [
#     [2, 3, 500],
#     [6, 9, 500],
#     [11, 9, 200]
# ]
data = [np.random.rand(3)*50 for i in range(random.randint(5, 50))]
circles = makeCircles(data)
showCircle(circles)
