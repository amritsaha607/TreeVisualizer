# %%
import sys
sys.path.append('../')

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

from utils import Circle, makeCircles, showCircle, showNodes

# %%
data = [np.random.rand(3)*1000 for i in range(10)]
texts = [random.randint(1, 10) for i in range(10)]

circles = makeCircles(data)

showNodes(circles, texts, mode='multi')
