# %%
import sys
sys.path.append('../')

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

from utils import Circle, makeCircles, showCircle, showTree
from treeNode import TreeNode
from helper import bakeTree

# %%
arr = [1, 2, 3, -1, -1, -1, -1]
root = bakeTree(arr)

showTree(root, focusNodes=[root])

# %%
arr = [
    1, 
    2, 3, 
    4, 5, -1, 6, 
    7, -1, -1, 9, 10, 11,
    -1, -1, -1, -1, -1, -1, -1, -1,
]
root = bakeTree(arr)

showTree(
    root, 
    focusNodes=[root, root.left.left, root.right.right.left]
)
